# %% [markdown]
# # Imágenes

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

img= cv2.imread('colores2.jpg')
img_RGB = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

fig, axs = plt.subplots(1,4,figsize=(20,5))

axs[0].imshow(img_RGB)
axs[0].set_title('Imagen Original')

fig_img=axs[1].imshow(img_RGB[...,0], cmap='gray')
fig.colorbar(fig_img, ax=axs[1],shrink=0.5)
axs[1].set_title('Canal Rojo')

fig_img=axs[2].imshow(img_RGB[...,1], cmap='gray')
fig.colorbar(fig_img, ax=axs[2],shrink=0.5)
axs[2].set_title('Canal Verde')

fig_img=axs[3].imshow(img_RGB[...,2], cmap='gray')
fig.colorbar(fig_img, ax=axs[3],shrink=0.5)
axs[3].set_title('Canal Azul')
# Out:
# Text(0.5, 1.0, 'Canal Azul')

# %%
img_RGB[:3,:3,:3]
# Out:
# array([[[34, 54, 81],
#         [33, 53, 80],
#         [31, 52, 81]],
#
#        [[34, 54, 81],
#         [33, 53, 80],
#         [31, 52, 81]],
#
#        [[34, 54, 81],
#         [34, 54, 81],
#         [33, 53, 80]]], dtype=uint8)

# %%
plt.imshow(img_RGB[:10,:10])

# %%
cv2.imwrite('imagen-nueva2.jpg',img_RGB) #Guardar con opencv

plt.imsave('imagen_nueva.jpg',cv2.cvtColor(img_RGB, cv2.COLOR_BGR2RGB))  #Guardar con pyplot

# %% [markdown]
# # Ejercicios para generar imágenes

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

plt.rcParams['figure.figsize'] = (10, 5)
size_imagen=100
R=np.ones((size_imagen,size_imagen))*125
G=np.ones((size_imagen,size_imagen))*108
B=np.ones((size_imagen,size_imagen))*200

imagen=np.dstack((R,G,B))
imagen=np.array(imagen,dtype=int)

plt.figure()
plt.imshow(imagen)
plt.title('imagen de color: Morado')
plt.show()

# %% [markdown]
# Escala de grises

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

img = cv2.imread('colores2.jpg', cv2.IMREAD_GRAYSCALE)

# Valores iniciales de profundidad de color
original = img.dtype

#  Transformar imagen a 16 bits
img16bits = np.uint16(img)
img_new = img16bits
print('profundidad de color : ', img_new.dtype)

#Guardado con cv2
cv2.imwrite('imagen-16cv.jpg', img_new)

#Guardado con pyplot
plt.imsave('imagen_plt.jpg', img_new, cmap='gray')

plt.figure(figsize=(16, 5))
plt.subplot(1, 2, 1)
plt.title('imagen original')
plt.imshow(img, cmap='gray')

plt.subplot(1, 2, 2)
plt.title('imagen con 16bits')
plt.imshow(img16bits, cmap='gray')
# Out:
# profundidad de color :  uint16
